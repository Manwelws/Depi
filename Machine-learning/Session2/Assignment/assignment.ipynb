# %%
from LinearRegressionGd import LinearRegressionGd

# %%
model = LinearRegressionGd(learning_rate=0.01, n_iters=1000)

# %%
X = [50, 60, 70, 80, 90]
y = [150, 180, 210, 240, 270]  # house price in thousands

# %%
model.fit(X,y)
# Out:
# /home/manwelw/depi/Depi/Machine-learning/Session2/Assignment/LinearRegressionGd.py:27: RuntimeWarning: overflow encountered in square
#   mse = np.sum((y_pred-y)**2)/m
# /home/manwelw/depi/Depi/Machine-learning/Session2/Assignment/LinearRegressionGd.py:22: RuntimeWarning: overflow encountered in multiply
#   w_grad = (1/m) * np.sum(error * X)
# /home/manwelw/depi/Depi/.venv/lib/python3.14/site-packages/numpy/_core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/manwelw/depi/Depi/Machine-learning/Session2/Assignment/LinearRegressionGd.py:24: RuntimeWarning: invalid value encountered in scalar subtract
#   self.weight -= self.learning_rate * w_grad

# %%
model.predict(70)
# Out:
# np.float64(nan)

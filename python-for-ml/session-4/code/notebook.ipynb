# %%
from myMath import factorial, isPrime
from myString import reverse_string

# %%
factorial(5)
# Out:
# 120

# %%
isPrime(20)
# Out:
# True

# %%
reverse_string("Hello World")
# Out:
# 'World Hello'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([1,2,3,4])
y = np.array([2,2.8,3.6,4.5])

# %%
#=======================
#Gradient Descent   
#======================
for i in range(epochs):
    y_hat = w * x + b
    error = y_hat - y
    #Gradients
    d_w = np.mean(error * x)
    d_b = np.mean(error)
    #update parameters
    w -= learning_rate * d_w
    b -= learning_rate * d_b
    #new line prediction
    y_hat = w*x +b   
    #cost
    cost = 0.5* np.mean((y_hat - y )**2)
    cost_values.append(cost)
    
    if (i +1) % 100 == 0 or i == 0:
        print(f"Epoch {i+1}:"
              f"cost = {cost},"
              f"w = {w}, "  
              f"b = {b} ")

plt.figure(figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #=======================
#       2 #Gradient Descent
#       3 #======================
# ----> 4 for i in range(epochs):
#       5     y_hat = w * x + b
#       6     error = y_hat - y
#       7     #Gradients
#
# NameError: name 'epochs' is not defined

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.scatter(x,y)
plt.plot(x, y_hat, color='r')

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data = pd.read_csv('Salary_Data.csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
plt.figure(figsize=(3,4))
sns.pairplot(data, x_vars=["YearsExperience"])

# %%
plt.figure(figsize=(3,4))
sns.pairplot(data, x_vars=["YearsExperience"], y_vars=["Salary"],size = 3, kind="scatter")
plt.xlabel("years")
plt.ylabel("salary")
plt.title("salary prediction")
plt.show()
# Out:
# /home/manwelw/depi/Depi/.venv/lib/python3.14/site-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
